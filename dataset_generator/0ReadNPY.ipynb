# %%
import numpy as np
import pandas as pd

data_array = np.load('Girl.npy', allow_pickle=True)

df = pd.DataFrame.from_records(data_array)
df
# Out:
#       Word  Frame        X00         Y00       Z00        X01         Y01  \
# 0     Girl      1 -12.038475   24.071261  0.463774 -12.038475   24.071261
# 1     Girl      2  -3.962504   52.028937  1.992968  -3.962504   52.028937
# 2     Girl      3  -4.183052   92.094520  6.335909  -4.183052   92.094520
# 3     Girl      4  -4.075910  642.111869  3.832657  -4.075910  642.111869
# 4     Girl      5   0.038440  -38.602620  0.755022   0.112906  -59.023292
# ...    ...    ...        ...         ...       ...        ...         ...
# 8123  Girl     15  -0.373683   13.953848  0.791891  -0.349386   18.343784
# 8124  Girl     16  -1.176031  -25.042544  2.266192  -1.176031  -25.042544
# 8125  Girl     17  -1.140367  -28.521609  2.261312  -1.140367  -28.521609
# 8126  Girl     18  -1.101435  -31.768244  1.858433  -1.101435  -31.768244
# 8127  Girl     19  -1.091181  -38.399838  1.794013  -1.091181  -38.399838
#
#            Z01        X02         Y02  ...  Z23  X24  Y24  Z24       X25  \
# ...

# %%
df[df['Frame'] == 20]
# Out:
#       Word  Frame       X00         Y00         Z00       X01         Y01  \
# 19    Girl     20 -3.848762  339.948277    2.386929 -3.848762  339.948277
# 39    Girl     20 -2.077472   80.897798  109.820499 -2.077472   80.897798
# 59    Girl     20 -0.971922 -182.173616  -20.273767 -0.971922 -182.173616
# 79    Girl     20 -1.928788   99.621082    5.768079 -1.928788   99.621082
# 99    Girl     20 -0.863095  335.163757  -59.717873 -0.863095  335.163757
# ...    ...    ...       ...         ...         ...       ...         ...
# 6831  Girl     20 -2.046656  814.566234    0.221610 -2.046656  814.566234
# 6851  Girl     20  0.242649  -10.534757    0.645937  0.242649  -10.534757
# 6871  Girl     20  0.038329  -10.650886    1.130346  0.038329  -10.650886
# 6891  Girl     20 -3.016516   19.807613    0.162705 -3.016516   19.807613
# 6911  Girl     20 -2.878665   48.657209   -0.339341 -2.878665   48.657209
#
#              Z01       X02         Y02  ...  Z23  X24  Y24  Z24       X25  \
# ...

# %%
df.to_csv('dataset.csv', index=False)
