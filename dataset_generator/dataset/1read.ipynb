# %%
import numpy as np
import pandas as pd

data_array = np.load('Hungry.npy', allow_pickle=True)

df = pd.DataFrame.from_records(data_array)
df
# Out:
#        Word  Frame       X00         Y00        Z00       X01         Y01  \
# 0    Hungry      1 -2.518232  -16.454789   0.150924 -2.518232  -16.454789
# 1    Hungry      2 -2.893950  179.871265   4.307169 -2.893950  179.871265
# 2    Hungry      3 -2.840397 -250.773359  21.108580 -2.840397 -250.773359
# 3    Hungry      4 -2.991858  182.208182   3.424894 -2.991858  182.208182
# 4    Hungry      5 -0.246600  -19.477403   2.057271 -0.181453  -13.214457
# ..      ...    ...       ...         ...        ...       ...         ...
# 853  Hungry     15 -0.155863   16.535912   2.151064 -0.026752   17.202643
# 854  Hungry     16 -0.151478   16.488927   1.865518 -0.023304   17.232691
# 855  Hungry     17 -0.161596   16.707986   1.285388 -0.030209   17.455065
# 856  Hungry     18 -0.163096   17.911313   1.109776 -0.033674   18.710675
# 857  Hungry     19 -0.170392   18.447504   1.133309 -0.041070   19.269539
#
#            Z01       X02         Y02  ...       Z62       X63       Y63  \
# ...

# %%
df.to_csv('dataset.csv', index=False)
