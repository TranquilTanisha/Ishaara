# %%
import numpy as np
data = np.load('Can_V1-0004.npy', allow_pickle=True)
data[1][:-1][:-3]
# Out:
# [[10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
#   -0.46234825167815247,
#   10.611710120970772,
#   2.546483101792329,
# ...
