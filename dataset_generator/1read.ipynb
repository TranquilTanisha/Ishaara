# %%
import numpy as np
import pandas as pd
# data = np.load('Boy_V1-0002.npy', allow_pickle=True)

data_array = np.load('dataset.npy', allow_pickle=True)

# Extract the dictionary from the numpy array
df = pd.DataFrame.from_records(data_array)
df
# Out:
#    Class Label     X0001         Y0001     Z0001     X0101         Y0101  \
# 0          Boy -0.290488    -75.818914 -3.229877 -0.166410    -77.328566
# 1          Boy -0.296255    -51.105509 -1.709560 -0.179443    -53.388619
# 2          Boy -0.823386    -21.517937 -3.879438 -0.750028    -19.029707
# 3          Boy -0.809016    -16.933169 -0.454784 -0.736722    -15.318171
# 4          Boy -0.176178   -446.572664  2.101218 -0.131045   -467.243357
# 5          Boy -1.216567    168.797190 -2.044628 -1.216567    168.797190
# 6          Boy -0.259257 -11096.285609 -3.519274 -0.165118 -11597.954982
# 7          Boy -1.201578     47.332398 -3.132390 -1.201578     47.332398
# 8          Boy -1.127109     32.695715  3.554801 -1.127109     32.695715
# 9          Boy -1.110157   -199.433070  4.839381 -1.110157   -199.433070
# 10         Boy -1.120658   -102.523983  3.710730 -1.120658   -102.523983
#
#        Z0101     X0201         Y0201     Z0201  ...     Z6220     X6320  \
# ...
