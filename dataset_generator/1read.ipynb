# %%
import numpy as np

# %%
import numpy as np
data = np.load('dataset.npy', allow_pickle=True)
data[0].keys()
# Out:
# dict_keys(['Class Label', 'X420', 'Y420', 'Z420', 'X430', 'Y430', 'Z430', 'X440', 'Y440', 'Z440', 'X450', 'Y450', 'Z450', 'X460', 'Y460', 'Z460', 'X470', 'Y470', 'Z470', 'X480', 'Y480', 'Z480', 'X490', 'Y490', 'Z490', 'X500', 'Y500', 'Z500', 'X510', 'Y510', 'Z510', 'X520', 'Y520', 'Z520', 'X530', 'Y530', 'Z530', 'X540', 'Y540', 'Z540', 'X550', 'Y550', 'Z550', 'X560', 'Y560', 'Z560', 'X570', 'Y570', 'Z570', 'X580', 'Y580', 'Z580', 'X590', 'Y590', 'Z590', 'X600', 'Y600', 'Z600', 'X610', 'Y610', 'Z610', 'X620', 'Y620', 'Z620', 'X630', 'Y630', 'Z630', 'X640', 'Y640', 'Z640', 'X650', 'Y650', 'Z650', 'X0198', 'Y0198', 'Z0198', 'X1198', 'Y1198', 'Z1198', 'X2198', 'Y2198', 'Z2198', 'X3198', 'Y3198', 'Z3198', 'X4198', 'Y4198', 'Z4198', 'X5198', 'Y5198', 'Z5198', 'X6198', 'Y6198', 'Z6198', 'X7198', 'Y7198', 'Z7198', 'X8198', 'Y8198', 'Z8198', 'X9198', 'Y9198', 'Z9198', 'X10198', 'Y10198', 'Z10198', 'X11198', 'Y11198', 'Z11198', 'X12198', 'Y12198', 'Z12198', 'X13198', 'Y13198', 'Z13198', 'X1419
# ...
